# %% [markdown]
# Um modelo de classificação de churn identificou que 2450 clientes têm probabilidade maior que 87% de
# serem churn na próxima semana.
#
# Este modelo possui uma precisão de 33%. Em cada 3 pessoas atendidas 2 não são churn e 1 é churn.
# Para cada erro ( pessoa não tem interesse em receber uma proposta de refinanciamento ), ocorre um
# custo médio de R$100,00
#
# **Qual cliente deve ser priorizado na fila de atendimento?**

# %% [markdown]
# Cada cliente só pode ser atendido por um ponto de atendimento.
#
# Cada atendente tem uma jornada diária de 6 horas (Segunda a Sexta) , sendo que a cada 90 minutos de
# atendimento, o atendente tem direito a um descanso de 10 minutos

# %% [markdown]
# ``` {python}
# PA1 = 8
# PA2 = 10
# PA3 = 12
# PA4 = 10
#
# PA1 = 9 - 15
# PA2 = 12 - 18
# PA3 = 9 - 15
# PA4 = 12 - 18
# ```

# %% [markdown]
# 2450 clientes
#
# 5%  - 30000          - 1.5%  a.m
# 10% - 20000 - 30000  - 1.6%  a.m
# 20% - 10000 - 20000  - 1.65% a.m
# 65% - 500   - 10000  - 1.70% a.m
#
# Prazo para financiamento é 72 parcelas.
#
# Clientes do sexo feminino atendem mais o
# telefone à tarde e na primeira metade da
# semana (segunda, terça e quarta).
#
# Clientes do sexo masculino atendem mais o
# telefone pela manhã e na segunda metade da
# semana (quarta, quinta e sexta).
#
# 60% dos clientes são do sexo feminino.
# 40% dos clientes são do sexo masculino.
#
# 30% dos clientes não atendem o telefone ou não
# tem interesse em ouvir a proposta.
#
# Para cada cliente que não quer ouvir a proposta,
# perde-se 30 segundos em média.

# %%
import pandas as pd
import numpy as np

class Client:
    
    def __init__(self,client_id,value, gender,rate,age,installments,churn_prob):
        self.client_id = client_id
        self.value = value
        self.gender = gender
        self.rate   = rate
        self.age    = age
        self.installments = installments
        self.churn_prob = churn_prob
        
    def __repr__(self):
        return "Client Id:{0}, Value: {1} , Gender: {2}, Rate: {3}, Age: {4},Installments : {5}, Churn Prob: {6}" \
    .format(self.client_id,self.value,self.gender,self.rate, self.age,self.installments, self.churn_prob)

class Clients:
    
    def __init__(self):
        self.clients = []
        clientes = pd.read_csv("clients.csv")
        
        for index, row in clientes.iterrows():
            c = Client(row['client_id'],row['value'],row['gender'],row['rate'],row['age'],row['installments'],row['churn_prob'])
            self.addClient(c)
     
    def addClient(self,client):
        self.clients.append(client)
        
    def nclients(self):
        return len(self.clients)

# %%
clients = Clients()

# %%
clients.clients[1]
# Out:
# Client Id:1.0, Value: 6438.02 , Gender: 1.0, Rate: 1.7, Age: 75.0,Installments : 36.0, Churn Prob: 0.91

# %%
def max_atendimentos(avg, tempo_total):
    return int(tempo_total/avg)
    
    
pa1 = max_atendimentos(8,330)
pa2 = max_atendimentos(10,330)
pa3 = max_atendimentos(12,330)
pa4 = max_atendimentos(10,330)

print(pa1 , pa2, pa3, pa4)
# Out:
# 41 33 27 33

# %%
def max_atendimentos_residuos(n,t):
    return int(((n * t) - (n - (n * 0.7)) * 0.5)/t + (n * 0.3))

m1 = max_atendimentos_residuos(pa1,8)
m2 = max_atendimentos_residuos(pa2,10)
m3 = max_atendimentos_residuos(pa3,12)
m4 = max_atendimentos_residuos(pa4,10)

print(m1, m2, m3 , m4)
# Out:
# 52 42 34 42

# %% [markdown]
# ### OTIMIZAÇÃO

# %%
from mip.model import Model, xsum, maximize
from mip.constants import BINARY

model = Model('fila-atendimento')

model.clear()
A = 4 
C = clients.nclients()
D = 5 

x = [[[model.add_var(name='x({},{},{})'.format(d, c, a), var_type=BINARY) for a in range(A)] for c in range(C)] for d in range(D)] # cliente, atendente , day

# %%
# cada cliente só pode ser atendido por um atendente
for c in range(C):
    model += xsum(x[d][c][a] for a in range(A) for d in range(D)) <= 1 
    

for d in range(D):
    model += xsum(x[d][c][0] for c in range(C)) <= 41 + 11 
    model += xsum(x[d][c][1] for c in range(C))  <= 33 + 9 
    model += xsum(x[d][c][2] for c in range(C))  <= 27 + 7 
    model += xsum(x[d][c][3] for c in range(C))  <= 33 + 9 
    

for d in range(D):
    for a in range(A):
        model +=  xsum(x[d][c][a] for c in range(C)) >= 20
        model +=  xsum(x[d][c][a] for c in range(C)) >= 20
        model +=  xsum(x[d][c][a] for c in range(C)) >= 20
        model +=  xsum(x[d][c][a] for c in range(C)) >= 20

    
# ##  add age constraint 
for d in range(D-1):
    model +=  xsum(clients.clients[c].age * x[d][c][0] for c in range(C)) <= xsum(clients.clients[c].age * x[d+1][c][0] for c in range(C) )
    model +=  xsum(clients.clients[c].age * x[d][c][1] for c in range(C)) <= xsum(clients.clients[c].age * x[d+1][c][1] for c in range(C) )
    model +=  xsum(clients.clients[c].age * x[d][c][2] for c in range(C)) <= xsum(clients.clients[c].age * x[d+1][c][2] for c in range(C) )
    model +=  xsum(clients.clients[c].age * x[d][c][3] for c in range(C)) <= xsum(clients.clients[c].age * x[d+1][c][3] for c in range(C) )

    
for a in range(A):
    model +=  xsum( clients.clients[c].gender + x[0][c][a] for c in range(C) ) <= xsum(clients.clients[c].gender + x[0][c][a] for c in range(C))  
    model +=  xsum( clients.clients[c].gender + x[1][c][a] for c in range(C) ) <= xsum(clients.clients[c].gender + x[1][c][a] for c in range(C))  
    model +=  xsum( clients.clients[c].gender + x[2][c][a] for c in range(C) ) <= xsum(clients.clients[c].gender + x[2][c][a] for c in range(C)) 

    model +=  xsum( (1 - clients.clients[c].gender ) * x[3][c][a] for c in range(C) ) >= xsum(clients.clients[c].gender * x[3][c][a] for c in range(C)) 
    model +=  xsum( (1 - clients.clients[c].gender ) * x[4][c][a] for c in range(C) ) >= xsum(clients.clients[c].gender * x[4][c][a] for c in range(C))

# %%
import numpy as np

## linearizar a exponencial ?
def juros_compostos(C,i,t):
    return (C*(1+(t/100))**i)

def juros_compostos2(C,i,t):
    return np.log(C)+i*np.log(1+(t/100))

# %%
# model.objective = maximize(
#     1/3 * xsum(
#         juros_compostos( clients.clients[c].value,clients.clients[c].installments, clients.clients[c].rate ) * x[d][c][a] for c in range(C) for a in range(A) for d in range(D)
#         ) - 2/3 * xsum(
#              100 * x[d][c][a] for c in range(C) for a in range(A) for d in range(D)
#         )
# )
    
model.objective = maximize(
        xsum(
            juros_compostos2( clients.clients[c].value,clients.clients[c].installments, clients.clients[c].rate ) * x[d][c][a] for c in range(C) for a in range(A) for d in range(D)
        ))

    
#model.optimize()
# colocar prazo na função objetivo

#model.max_gap = 0.05

# model.clique = 2,
# model.cut_passes = 7

# if set to 1 (FEASIBILITY) then the search process will
# focus on try to find quickly feasible solutions and improving them; if set to 2 (OPTIMALITY)
# then the search process will try to find a provable optimal solution
model.emphasis = 2

model.optimize(max_seconds=600)
# Out:
# Welcome to the CBC MILP Solver
# Version: Trunk
# Build Date: Oct 24 2021
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 29400 small elements
# Coin0506I Presolve 2514 (-72) rows, 49000 (0) columns and 245000 (-147000) elements
# Clp0030I 11 infeas 10.209078, obj 9275.7362 - mu 0.014067082, its 105, 19045 interior
# Clp0030I 21 infeas 0.022437231, obj 9244.5137 - mu 0.00052084675, its 105, 27615 interior
# Clp0030I 30 infeas 0.00050523836, obj 9244.7733 - mu 1.9284834e-05, its 105, 28503 interior
# Clp0030I 40 infeas 1.7912826e-05, obj 9244.7828 - mu 7.1403884e-07, its 105, 28538 interior
# Clp0030I 50 infeas 6.4773186e-06, obj 9244.7832 - mu 8.8117688e-09, its 105, 28538 interior
# Clp1000I sum of infeasibilities 2.34296e-08 - average 9.31964e-12, 20462 fixed columns
# Coin0506I Presolve 1823 (-691) rows, 28538 (-20462) columns and 142734 (-102266) elements
# Clp0006I 0  Obj 9244.7832 Dual inf 29932246 (28538)
# Clp0029I End of values pass after 28538 iterations
# Clp0014I Perturbing problem by 0.001% of 1.0398853 - largest nonzero change 2.9976734e-05 ( 0.0014988367%) - largest zero change 2.9576128e-05
# Clp0000I Optimal - objective value 9276.0011
# Clp0000I Optimal - objective value 9276.0011
# Coin0511I After Postsolve, objective 9276.0011, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 9276.0011
# Clp0000I Optimal - objective value 9276.0011
# Clp0000I Optimal - objective value 9276.0011
# Clp0000I Optimal - objective value 9276.0011
# Coin0511I After Postsolve, objective 9276.0011, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 9276.001052 - 0 iterations time 4.212, Presolve 0.05, Idiot 4.15
#
# Starting MIP optimization
# Cgl0008I 2450 inequality constraints converted to equality constraints
# Cgl0005I 2450 SOS with 51450 members
# Cgl0004I processed model has 2494 rows, 51450 columns (51450 integer (51450 of which binary)) and 198450 elements
# Coin3009W Conflict graph built in 0.034 seconds, density: 0.011%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0045I Nauty sparseSpace 1143270 affine 135120 coefficient count 189065
# Cbc0045I Nauty: 143024 orbits (12250 useful covering 24500 variables), 1 generators, group size: 2 - sparse size 1143270 - took 10.292 seconds
# Cbc0038I Initial state - 65 integers unsatisfied sum - 17.4352
# Cbc0038I Pass   1: suminf.    1.10991 (6) obj. -9271.48 iterations 625
# Cbc0038I Pass   2: suminf.    0.30991 (4) obj. -9271.67 iterations 2
# Cbc0038I Pass   3: suminf.    0.30667 (3) obj. -9256.59 iterations 16
# Cbc0038I Pass   4: suminf.    0.18667 (3) obj. -9257.73 iterations 12
# Cbc0038I Pass   5: suminf.    5.01584 (18) obj. -8821.25 iterations 1104
# Cbc0038I Pass   6: suminf.    0.25532 (4) obj. -8819.4 iterations 543
# Cbc0038I Pass   7: suminf.    0.37333 (2) obj. -8795.92 iterations 223
# Cbc0038I Pass   8: suminf.    0.05333 (2) obj. -8798.99 iterations 255
# Cbc0038I Pass   9: suminf.    4.59398 (12) obj. -8657.45 iterations 1137
# Cbc0038I Pass  10: suminf.    0.27047 (4) obj. -8654.11 iterations 600
# Cbc0038I Pass  11: suminf.    0.77333 (2) obj. -8630.57 iterations 328
# Cbc0038I Pass  12: suminf.    0.53333 (2) obj. -8632.71 iterations 85
# Cbc0038I Pass  13: suminf.    0.37333 (2) obj. -8635.13 iterations 216
# Cbc0038I Pass  14: suminf.    0.13333 (2) obj. -8637.27 iterations 377
# Cbc0038I Pass  15: suminf.    5.22078 (18) obj. -8581.11 iterations 843
# Cbc0038I Pass  16: suminf.    0.16126 (4) obj. -8579.05 iterations 520
# Cbc0038I Pass  17: suminf.    0.20000 (1) obj. -8550.48 iterations 323
# Cbc0038I Pass  18: suminf.    0.09333 (1) obj. -8551.57 iterations 438
# Cbc0038I Pass  19: suminf.    6.43681 (18) obj. -8556.76 iterations 752
# Cbc0038I Pass  20: suminf.    0.33551 (7) obj. -8549.76 iterations 671
# Cbc0038I Pass  21: suminf.    1.81333 (6) obj. -8526.08 iterations 356
# Cbc0038I Pass  22: suminf.    0.78667 (5) obj. -8536.05 iterations 218
# Cbc0038I Pass  23: suminf.    1.22667 (5) obj. -8530.73 iterations 318
# Cbc0038I Pass  24: suminf.    0.70667 (5) obj. -8535.76 iterations 180
# Cbc0038I Pass  25: suminf.    1.30667 (5) obj. -8531.02 iterations 299
# Cbc0038I Pass  26: suminf.    7.54365 (20) obj. -8533.44 iterations 740
# Cbc0038I Pass  27: suminf.    0.20270 (3) obj. -8531.95 iterations 563
# Cbc0038I Pass  28: suminf.    0.61333 (2) obj. -8517.27 iterations 324
# Cbc0038I Pass  29: suminf.    0.41333 (2) obj. -8519.3 iterations 149
# Cbc0038I Pass  30: suminf.    0.33333 (2) obj. -8522.04 iterations 256
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 46992 integers at bound fixed and 1088 continuous
# Cbc0038I Full problem 2494 rows 51450 columns, reduced to 423 rows 1918 columns
# Cbc0038I Mini branch and bound improved solution from 1.79769e+308 to -9276 (14.30 seconds)
# Cbc0038I After 14.32 seconds - Feasibility pump exiting with objective of -9276 - took 3.08 seconds
# Cbc0012I Integer solution of -9276.0011 found by feasibility pump after 0 iterations and 0 nodes (14.33 seconds)
# Cbc0001I Search completed - best objective -9276.001052194111, took 0 iterations and 0 nodes (14.34 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Total time (CPU seconds):       14.32   (Wallclock seconds):       14.43
# <OptimizationStatus.OPTIMAL: 0>

# %%
clientes_atendidos = 0
for a in range(A):
    for d in range(D):
        selected = [i for i in range(C) if x[d][i][a].x >= 0.99]
        logvalue = round(sum(juros_compostos2(clients.clients[s].value,clients.clients[s].installments, clients.clients[s].rate ) for s in selected),2)
        value = round(sum(juros_compostos(clients.clients[s].value,clients.clients[s].installments, clients.clients[s].rate ) for s in selected),2)*0.7*1/3
        print("{} + {}".format(logvalue,value))
        mean_age = sum(clients.clients[s].age for s in selected) / len(selected)
        male = len(selected)  - sum(clients.clients[s].gender for s in selected)
        female =  len(selected) - male
        print('Atendente {}: day {} clients: {} , Male: {} , Female: {} , value {}, sequence {} , Mean Age : {}'.format(a,d,len(selected),male, female, value,selected,mean_age))
        
        for c in selected:
            print(clients.clients[c])
        print('-'*30)
        clientes_atendidos += len(selected)

print(clientes_atendidos)
# Out:
# 567.92 + 772260.6756666666
# Atendente 0: day 0 clients: 52 , Male: 24.0 , Female: 28.0 , value 772260.6756666666, sequence [37, 129, 154, 156, 160, 162, 170, 179, 192, 219, 222, 242, 252, 288, 357, 361, 365, 461, 536, 571, 631, 734, 766, 836, 844, 879, 933, 974, 1018, 1019, 1045, 1207, 1287, 1306, 1315, 1324, 1430, 1577, 1641, 1762, 1863, 1892, 1916, 2017, 2058, 2178, 2218, 2231, 2304, 2329, 2380, 2447] , Mean Age : 63.09615384615385
# Client Id:37.0, Value: 20338.74 , Gender: 0.0, Rate: 1.6, Age: 73.0,Installments : 36.0, Churn Prob: 0.92
# Client Id:129.0, Value: 23867.06 , Gender: 0.0, Rate: 1.6, Age: 61.0,Installments : 72.0, Churn Prob: 0.96
# Client Id:154.0, Value: 9790.85 , Gender: 1.0, Rate: 1.7, Age: 55.0,Installments : 72.0, Churn Prob: 0.97
# Client Id:156.0, Value: 12606.15 , Gender: 1.0, Rate: 1.65, Age: 62.0,Installments : 72.0, Churn Prob: 0.95
# Client Id:160.0, Value: 12244.63 , Gender: 0.0, Rate: 1.65, Age: 57.0,Installments : 72.0, Churn Prob: 0.97
# Client Id:162.0, Value: 24871.8 , Gender: 1.0, Rate: 1.6, Age: 59.0,Installments : 72.0, Churn Prob: 0.97
# Client Id:170.0, Value: 18589.87 , Gender: 1.0, Rate: 1.65, Age: 74.0,Installments : 36.0, Churn Prob: 0.93
# Client Id:179.0, Value: 19258.04 , Gender: 0.0, Rate: 1.65, Age: 72.0,Installments : 48.0, Churn Prob: 0.99
# Client Id:192.0, Value: 14862.26 , Gender: 1.0, Rate: 1.65, Age: 57.0,Installments : 72.0, Churn Prob: 0.89
# Client Id:219.0, Value: 39477.93 , Gender: 0.0, Rate: 1.5, Age: 75.0,Installments : 36.0, Churn Prob: 0.92
# Client Id:222.0, Value: 24767.27 , Gender: 1.0, Rate: 1.6, Age: 58.0,Installments : 72.0, Churn Prob: 0.95
# Client Id:242.0, Value: 17476.82 , Gender: 0.0, Rate: 1.65, Age: 68.0,Installments : 48.0, Churn Prob: 0.93
# Client Id:252.0, Value: 23493.29 , Gender: 1.0, Rate: 1.6, Age: 57.0,Installments : 72.0, Churn Prob: 0.9
# Client Id:288.0, Value: 22315.2 , Gender: 1.0, Rate: 1.6, Age: 71.0,Installments : 48.0, Churn Prob: 0.95
# Client Id:357.0, Value: 13430.18 , Gender: 0.0, Rate: 1.65, Age: 64.0,Installments : 72.0, Churn Prob: 0.95
# Client Id:361.0, Value: 25672.52 , Gender: 0.0, Rate: 1.6, Age: 55.0,Installments : 72.0, Churn Prob: 0.95
# Client Id:365.0, Value: 50891.98 , Gender: 1.0, Rate: 1.5, Age: 59.0,Installments : 72.0, Churn Prob: 0.93
# Client Id:461.0, Value: 20793.77 , Gender: 1.0, Rate: 1.6, Age: 74.0,Installments : 36.0, Churn Prob: 0.93
# Client Id:536.0, Value: 18426.75 , Gender: 1.0, Rate: 1.65, Age: 74.0,Installments : 36.0, Churn Prob: 0.97
# Client Id:571.0, Value: 28708.82 , Gender: 1.0, Rate: 1.6, Age: 56.0,Installments : 72.0, Churn Prob: 0.91
# Client Id:631.0, Value: 27934.19 , Gender: 1.0, Rate: 1.6, Age: 65.0,Installments : 72.0, Churn Prob: 0.97
# Client Id:734.0, Value: 28997.14 , Gender: 0.0, Rate: 1.6, Age: 65.0,Installments : 72.0, Churn Prob: 0.88
# Client Id:766.0, Value: 9717.64 , Gender: 0.0, Rate: 1.7, Age: 59.0,Installments : 72.0, Churn Prob: 0.96
# Client Id:836.0, Value: 58775.57 , Gender: 1.0, Rate: 1.5, Age: 66.0,Installments : 72.0, Churn Prob: 0.87
# Client Id:844.0, Value: 64532.96 , Gender: 1.0, Rate: 1.5, Age: 71.0,Installments : 48.0, Churn Prob: 0.95
# Client Id:879.0, Value: 11267.05 , Gender: 0.0, Rate: 1.65, Age: 57.0,Installments : 72.0, Churn Prob: 0.93
# Client Id
0, Rate: 1.6, Age: 71.0,Installments : 48.0, Churn Prob: 0.89
# Client Id:127.0, Value: 14195.48 , Gender: 1.0, Rate: 1.65, Age: 67.0,Installments : 48.0, Churn Prob: 0.98
# Client Id:155.0, Value: 48627.32 , Gender: 1.0, Rate: 1.5, Age: 66.0,Installments : 72.0, Churn Prob: 0.99
# Client Id:239.0, Value: 18341.17 , Gender: 1.0, Rate: 1.65, Age: 71.0,Installments : 48.0, Churn Prob: 0.88
# Client Id:306.0, Value: 10875.71 , Gender: 0.0, Rate: 1.65, Age: 66.0,Installments : 72.0, Churn Prob: 0.91
# Client Id:388.0, Value: 15007.67 , Gender: 1.0, Rate: 1.65, Age: 64.0,Installments : 72.0, Churn Prob: 0.93
# Client Id:493.0, Value: 15472.37 , Gender: 0.0, Rate: 1.65, Age: 61.0,Installments : 72.0, Churn Prob: 0.95
# Client Id:507.0, Value: 9323.39 , Gender: 1.0, Rate: 1.7, Age: 57.0,Installments : 72.0, Churn Prob: 0.9
# Client Id:520.0, Value: 22967.39 , Gender: 0.0, Rate: 1.6, Age: 72.0,Installments : 48.0, Churn Prob: 0.89
# Client Id:597.0, Value: 9491.33 , Gender: 1.0, Rate: 1.7, Age: 66.0,Installments : 72.0, Churn Prob: 0.89
# Client Id:647.0, Value: 19125.18 , Gender: 1.0, Rate: 1.65, Age: 58.0,Installments : 72.0, Churn Prob: 0.97
# Client Id:663.0, Value: 14821.78 , Gender: 0.0, Rate: 1.65, Age: 57.0,Installments : 72.0, Churn Prob: 0.9
# Client Id:838.0, Value: 20807.91 , Gender: 1.0, Rate: 1.6, Age: 74.0,Installments : 36.0, Churn Prob: 0.92
# Client Id:859.0, Value: 22148.05 , Gender: 0.0, Rate: 1.6, Age: 60.0,Installments : 72.0, Churn Prob: 0.89
# Client Id:1017.0, Value: 12382.79 , Gender: 0.0, Rate: 1.65, Age: 61.0,Installments : 72.0, Churn Prob: 0.92
# Client Id:1022.0, Value: 18288.78 , Gender: 1.0, Rate: 1.65, Age: 75.0,Installments : 36.0, Churn Prob: 0.96
# Client Id:1024.0, Value: 10554.08 , Gender: 0.0, Rate: 1.65, Age: 63.0,Installments : 72.0, Churn Prob: 0.88
# Client Id:1039.0, Value: 19725.55 , Gender: 1.0, Rate: 1.65, Age: 63.0,Installments : 72.0, Churn Prob: 0.96
# Client Id:1091.0, Value: 67478.01 , Gender: 1.0, Rate: 1.5, Age: 59.0,Installments : 72.0, Churn Prob: 0.89
# Client Id:1178.0, Value: 9664.03 , Gender: 1.0, Rate: 1.7, Age: 57.0,Installments : 72.0, Churn Prob: 0.98
# Client Id:1299.0, Value: 18651.23 , Gender: 1.0, Rate: 1.65, Age: 60.0,Installments : 72.0, Churn Prob: 0.9
# Client Id:1336.0, Value: 14762.24 , Gender: 1.0, Rate: 1.65, Age: 70.0,Installments : 48.0, Churn Prob: 0.96
# Client Id:1404.0, Value: 15525.51 , Gender: 0.0, Rate: 1.65, Age: 70.0,Installments : 48.0, Churn Prob: 0.91
# Client Id:1443.0, Value: 18426.39 , Gender: 1.0, Rate: 1.65, Age: 73.0,Installments : 36.0, Churn Prob: 0.98
# Client Id:1623.0, Value: 16114.58 , Gender: 1.0, Rate: 1.65, Age: 70.0,Installments : 48.0, Churn Prob: 0.93
# Client Id:1666.0, Value: 9427.61 , Gender: 0.0, Rate: 1.7, Age: 62.0,Installments : 72.0, Churn Prob: 0.95
# Client Id:1709.0, Value: 15955.08 , Gender: 0.0, Rate: 1.65, Age: 72.0,Installments : 48.0, Churn Prob: 0.89
# Client Id:1737.0, Value: 9728.48 , Gender: 0.0, Rate: 1.7, Age: 65.0,Installments : 72.0, Churn Prob: 0.92
# Client Id:1744.0, Value: 18958.81 , Gender: 0.0, Rate: 1.65, Age: 67.0,Installments : 48.0, Churn Prob: 0.94
# Client Id:1750.0, Value: 9684.07 , Gender: 0.0, Rate: 1.7, Age: 57.0,Installments : 72.0, Churn Prob: 0.99
# Client Id:1765.0, Value: 11980.88 , Gender: 0.0, Rate: 1.65, Age: 62.0,Installments : 72.0, Churn Prob: 0.96
# Client Id:1820.0, Value: 13253.54 , Gender: 0.0, Rate: 1.65, Age: 61.0,Installments : 72.0, Churn Prob: 0.91
# Client Id:1869.0, Value: 14237.26 , Gender: 1.0, Rate: 1.65, Age: 58.0,Installments : 72.0, Churn Prob: 0.92
# Client Id:1883.0, Value: 15020.68 , Gender: 1.0, Rate: 1.65, Age: 66.0,Installments : 72.0, Churn Prob: 0.95
# Client Id:2050.0, Value: 20886.41 , Gender: 1.0, Rate: 1.6, Age: 62.0,Installments : 72.0, Churn Prob: 0.89
# Client Id:2066.0, Value: 32727.37 , Gender: 1.0, Rate: 1.5, Age: 58.0,Installments : 72.0, Churn Prob: 0.92
# Client Id:2075.0, Value: 16129.27 , Gender: 1.0, Rate: 1.65, Age: 69.0,Installments : 48.0, Churn Prob: 0.89
# Client Id:2122.0, Value: 17893.47 , Gender: 1.0, Rate: 1.65, Age: 64.0,Installments : 72.0, Churn Prob: 0.91
# Client Id:2177.0, Value: 40118.9 , Gender: 1.0, Rate: 1.5, Age: 71.0,Installments : 48.0, Churn Prob: 0.96
# Client Id:2194.0, Value: 14910.66 , Gender: 0.0, Rate: 1.65, Age: 56.0,Installments : 72.0, Churn Prob: 0.9
# Client Id:2206.0, Value: 9449.4 , Gender: 0.0, Rate: 1.7, Age: 61.0,Installments : 72.0, Churn Prob: 0.98
# Client Id:2242.0, Value: 29266.62 , Gender: 1.0, Rate: 1.6, Age: 67.0,Installments : 48.0, Churn Prob: 0.93
# Client Id:2264.0, Value: 20167.44 , Gender: 0.0, Rate: 1.6, Age: 60.0,Installments : 72.0, Churn Prob: 0.96
# Client Id:2330.0, Value: 10042.74 , Gender: 1.0, Rate: 1.65, Age: 56.0,Installments : 72.0, Churn Prob: 0.93
# ------------------------------
# 568.54 + 741050.9983333334
# Atendente 0: day 2 clients: 52 , Male: 15.0 , Female: 37.0 , value 741050.9983333334, sequence [331, 701, 870, 873, 915, 940, 951, 1011, 1015, 1076, 1213, 1228, 1231, 1238, 1250, 1268, 1402, 1459, 1464, 1479, 1484, 1492, 1512, 1525, 1526, 1547, 1549, 1553, 1567, 1574, 1581, 1584, 1605, 1607, 1642, 1656, 1668, 1669, 1697, 1702, 1716, 1720, 1726, 1741, 1788, 1949, 1975, 2008, 2032, 2080, 2130, 2438] , Mean Age : 64.4423076923077
# Client Id:331.0, Value: 14240.04 , Gender: 1.0, Rate: 1.65, Age: 66.0,Installments : 72.0, Churn Prob: 0.93
# Client Id:701.0, Value: 24402.73 , Gender: 1.0, Rate: 1.6, Age: 75.0,Installments : 36.0, Churn Prob: 0.87
# Client Id:870.0, Value: 11256.97 , Gender: 0.0, Rate: 1.65, Age: 56.0,Installments : 72.0, Churn Prob: 0.94
# Client Id:873.0, Value: 9796.83 , Gender: 0.0, Rate: 1.7, Age: 66.0,Installments : 72.0, Churn Prob: 0.88
# Client Id:915.0, Value: 18550.28 , Gender: 1.0, Rate: 1.65, Age: 70.0,Installments : 48.0, Churn Prob: 0.95
# Client Id:940.0, Value: 13810.79 , Gender: 1.0, Rate: 1.65, Age: 56.0,Installments : 72.0, Churn Prob: 0.99
# Client Id:951.0, Value: 19330.92 , Gender: 1.0, Rate: 1.65, Age: 73.0,Installments : 36.0, Churn Prob: 0.91
# Client Id:1011.0, Value: 9077.79 , Gender: 1.0, Rate: 1.7, Age: 61.0,Installments : 72.0, Churn Prob: 0.9
# Client Id:1015.0, Value: 25585.35 , Gender: 1.0, Rate: 1.6, Age: 55.0,Installments : 72.0, Churn Prob: 0.88
# Client Id:1076.0, Value: 13774.25 , Gender: 1.0, Rate: 1.65, Age: 63.0,Installments : 72.0, Churn Prob: 0.98
# Client Id:1213.0, Value: 28350.74 , Gender: 1.0, Rate: 1.6, Age: 59.0,Installments : 72.0, Churn Prob: 0.96
# Client Id:1228.0, Value: 28931.33 , Gender: 1.0, Rate: 1.6, Age: 62.0,Installments : 72.0, Churn Prob: 0.95
# Client Id:1231.0, Value: 9288.74 , Gender: 1.0, Rate: 1.7, Age: 62.0,Installments : 72.0, Churn Prob: 0.87
# Client Id:1238.0, Value: 10046.63 , Gender: 1.0, Rate: 1.65, Age: 61.0,Installments : 72.0, Churn Prob: 0.95
# Client Id:1250.0, Value: 9938.24 , Gender: 0.0, Rate: 1.7, Age: 65.0,Installments : 72.0, Churn Prob: 0.89
# Client Id:1268.0, Value: 17941.93 , Gender: 1.0, Rate: 1.65, Age: 72.0,Installments : 48.0, Churn Prob: 0.92
# Client Id:1402.0, Value: 17670.39 , Gender: 1.0, Rate: 1.65, Age: 56.0,Installments : 72.0, Churn Prob: 0.93
# Client Id:1459.0, Value: 63937.63 , Gender: 0.0, Rate: 1.5, Age: 62.0,Installments : 72.0, Churn Prob: 0.93
# Client Id:1464.0, Value: 21730.66 , Gender: 0.0, Rate: 1.6, Age: 62.0,Installments : 72.0, Churn Prob: 0.93
# Client Id:1479.0, Value: 59463.51 , Gender: 0.0, Rate: 1.5, Age: 73.0,Installments : 36.0, Churn Prob: 0.95
# Client Id:1484.0, Value: 26775.19 , Gender: 1.0, Rate: 1.6, Age: 58.0,Installments : 72.0, Churn Prob: 0.98
# Client Id:1492.0, Value: 38146.58 , Gender: 1.0, Rate: 1.5, Age: 75.0,Installments : 36.0, Churn Prob: 0.91
# Client Id:1512.0, Value: 29084.98 , Gender: 0.0, Rate: 1.6, Age: 74.0,Installments : 36.0, Churn Prob: 0.94
# Client Id:1525.0, Value: 9695.28 , Gender: 1.0, Rate: 1.7, Age: 63.0,Installments : 72.0, Churn Prob: 0.94
# Client Id:1526.0, Value: 16949.7 , Gender: 1.0, Rate: 1.65, Age: 62.0,Installments : 72.0, Churn Prob: 0.99
# Client Id:1547.0, Value: 26831.04 , Gender: 1.0, Rate: 1.6, Age: 67.0,Installments : 48.0, Churn Prob: 0.98
# Client Id:1549.0, Value: 36458.16 , Gender: 1.0, Rate: 1.5, Age: 70.0,Installments : 48.0, Churn Prob: 0.94
# Client Id:1553.0, Value: 13201.46 , Gender: 1.0, Rate: 1.65, Age: 59.0,Installments : 72.0, Churn Prob: 0.88
# Client Id:1567.0, Value: 27336.63 , Gender: 1.0, Rate: 1.6, Age: 56.0,Installments : 72.0, Churn Prob: 0.96
# Client Id:1574.0, Value: 26022.38 , Gender: 1.0, Rate: 1.6, Age: 73.0,Installments : 36.0, Churn Prob: 0.9
# Client Id:1581.0, Value: 49505.62 , Gender: 1.0, Rate: 1.5, Age: 74.0,Installments : 36.0, Churn Prob: 0.93
# Client Id:1584.0, Value: 26577.3 , Gender: 1.0, Rate: 1.6, Age: 68.0,Installments : 48.0, Churn Prob: 0.94
# Client Id:1605.0, Value: 25265.42 , Gender: 1.0, Rate: 1.6, Age: 66.0,Installments : 72.0, Churn Prob: 0.94
# Client Id:1607.0, Value: 24497.62 , Gender: 1.0, Rate: 1.6, Age: 65.0,Installments : 72.0, Churn Prob: 0.96
# Client Id:1642.0, Value: 27148.38 , Gender: 0.0, Rate: 1.6, Age: 69.0,Installments : 48.0, Churn Prob: 0.98
# Client Id:1656.0, Value: 16608.37 , Gender: 0.0, Rate: 1.65, Age: 71.0,Installments : 48.0, Churn Prob: 0.89
# Client Id:1668.0, Value: 21514.27 , Gender: 1.0, Rate: 1.6, Age: 59.0,Installments : 72.0, Churn Prob: 0.91
# Client Id:1669.0, Value: 15077.34 , Gender: 0.0, Rate: 1.65, Age: 61.0,Installments : 72.0, Churn Prob: 0.93
# Client Id:1697.0, Value: 16029.02 , Gender: 0.0, Rate: 1.65, Age: 58.0,Installments : 72.0, Churn Prob: 0.97
# Client Id:1702.0, Value: 66329.67 , Gender: 1.0, Rate: 1.5, Age: 71.0,Installments : 48.0, Churn Prob: 0.98
# Client Id:1716.0, Value: 24092.41 , Gender: 0.0, Rate: 1.6, Age: 58.0,Installments : 72.0, Churn Prob: 0.96
# Client Id:1720.0, Value: 12583.53 , Gender: 1.0, Rate: 1.65, Age: 65.0,Installments : 72.0, Churn Prob: 0.91
# Client Id:1726.0, Value: 28151.3 , Gender: 0.0, Rate: 1.6, Age: 73.0,Installments : 36.0, Churn Prob: 0.9
# Client Id:1741.0, Value: 25320.86 , Gender: 1.0, Rate: 1.6, Age: 73.0,Installments : 36.0, Churn Prob: 0.91
# Client Id:1788.0, Value: 18293.64 , Gender: 0.0, Rate: 1.65, Age: 67.0,Installments : 48.0, Churn Prob: 0.89
# Client Id:1949.0, Value: 21775.25 , Gender: 1.0, Rate: 1.6, Age: 61.0,Installments : 72.0, Churn Prob: 0.96
# Client Id:1975.0, Value: 17579.07 , Gender: 1.0, Rate: 1.65, Age: 61.0,Installments : 72.0, Churn Prob: 0.89
# Client Id:2008.0, Value: 19215.48 , Gender: 0.0, Rate: 1.65, Age: 55.0,Installments : 72.0, Churn Prob: 0.88
# Client Id:2032.0, Value: 28921.72 , Gender: 1.0, Rate: 1.6, Age: 63.0,Installments : 72.0, Churn Prob: 0.96
# Client Id:2080.0, Value: 9652.44 , Gender: 1.0, Rate: 1.7, Age: 63.0,Installments : 72.0, Churn Prob: 0.98
# Client Id:2130.0, Value: 34242.58 , Gender: 1.0, Rate: 1.5, Age: 61.0,Installments : 72.0, Churn Prob: 0.88
# Client Id:2438.0, Value: 17572.62 , Gender: 1.0, Rate: 1.65, Age: 57.0,Installments : 72.0, Churn Prob: 0.97
# ------------------------------
# 566.39 + 714434.497
# Atendente 0: day 3 clients: 52 , Male: 26.0 , Female: 26.0 , value 714434.497, sequence [221, 267, 319, 433, 469, 474, 510, 518, 530, 535, 570, 574, 576, 582, 585, 591, 614, 623, 624, 703, 742, 756, 786, 792, 852, 883, 896, 992, 1126, 1151, 1245, 1291, 1361, 1406, 1524, 1550, 1769, 1813, 1871, 1958, 2027, 2104, 2120, 2159, 2163, 2165, 2244, 2290, 2301, 2332, 2343, 2429] , Mean Age : 65.03846153846153
# Client Id:221.0, Value: 19381.35 , Gender: 1.0, Rate: 1.65, Age: 62.0,Installments : 72.0, Churn Prob: 0.98
# Client Id:267.0, Value: 18945.8 , Gender: 0.0, Rate: 1.65, Age: 74.0,Installments : 36.0, Churn Prob: 0.95
# Client Id:319.0, Value: 24140.38 , Gender: 1.0, Rate: 1.6, Age: 65.0,Installments : 72.0, Churn Prob: 0.87
# Client Id:433.0, Value: 49926.14 , Gender: 1.0, Rate: 1.5, Age: 65.0,Installments : 72.0, Churn Prob: 0.89
# Client Id:469.0, Value: 28228.4 , Gender: 1.0, Rate: 1.6, Age: 68.0,Installments : 48.0, Churn Prob: 0.98
# Client Id:474.0, Value: 17631.86 , Gender: 0.0, Rate: 1.65, Age: 57.0,Installments : 72.0, Churn Prob: 0.9
# Client Id:510.0, Value: 23487.19 , Gender: 1.0, Rate: 1.6, Age: 72.0,Installments : 48.0, Churn Prob: 0.9
# Client Id:518.0, Value: 22660.29 , Gender: 1.0, Rate: 1.6, Age: 57.0,Installments : 72.0, Churn Prob: 0.87
# Client Id
0,Installments : 72.0, Churn Prob: 0.92
# Client Id:909.0, Value: 9441.45 , Gender: 0.0, Rate: 1.7, Age: 58.0,Installments : 72.0, Churn Prob: 0.92
# Client Id:923.0, Value: 24532.7 , Gender: 1.0, Rate: 1.6, Age: 65.0,Installments : 72.0, Churn Prob: 0.91
# Client Id:1063.0, Value: 16837.19 , Gender: 0.0, Rate: 1.65, Age: 57.0,Installments : 72.0, Churn Prob: 0.89
# Client Id:1071.0, Value: 18348.98 , Gender: 1.0, Rate: 1.65, Age: 62.0,Installments : 72.0, Churn Prob: 0.89
# Client Id:1143.0, Value: 18958.75 , Gender: 1.0, Rate: 1.65, Age: 64.0,Installments : 72.0, Churn Prob: 0.89
# Client Id:1182.0, Value: 10340.88 , Gender: 0.0, Rate: 1.65, Age: 57.0,Installments : 72.0, Churn Prob: 0.93
# Client Id:1241.0, Value: 10326.9 , Gender: 1.0, Rate: 1.65, Age: 55.0,Installments : 72.0, Churn Prob: 0.91
# Client Id:1244.0, Value: 18162.45 , Gender: 1.0, Rate: 1.65, Age: 66.0,Installments : 72.0, Churn Prob: 0.93
# Client Id:1260.0, Value: 13708.81 , Gender: 0.0, Rate: 1.65, Age: 57.0,Installments : 72.0, Churn Prob: 0.89
# Client Id:1348.0, Value: 9628.01 , Gender: 0.0, Rate: 1.7, Age: 61.0,Installments : 72.0, Churn Prob: 0.9
# Client Id:1356.0, Value: 9540.32 , Gender: 1.0, Rate: 1.7, Age: 63.0,Installments : 72.0, Churn Prob: 0.92
# Client Id:1357.0, Value: 29639.44 , Gender: 1.0, Rate: 1.6, Age: 69.0,Installments : 48.0, Churn Prob: 0.93
# Client Id:1419.0, Value: 9959.21 , Gender: 0.0, Rate: 1.7, Age: 63.0,Installments : 72.0, Churn Prob: 0.92
# Client Id:1521.0, Value: 9368.98 , Gender: 0.0, Rate: 1.7, Age: 60.0,Installments : 72.0, Churn Prob: 0.99
# Client Id:1617.0, Value: 9361.36 , Gender: 0.0, Rate: 1.7, Age: 65.0,Installments : 72.0, Churn Prob: 0.96
# Client Id:1808.0, Value: 9982.88 , Gender: 0.0, Rate: 1.7, Age: 63.0,Installments : 72.0, Churn Prob: 0.9
# Client Id:1852.0, Value: 13441.47 , Gender: 1.0, Rate: 1.65, Age: 64.0,Installments : 72.0, Churn Prob: 0.92
# Client Id:1954.0, Value: 17772.67 , Gender: 1.0, Rate: 1.65, Age: 65.0,Installments : 72.0, Churn Prob: 0.95
# Client Id:1963.0, Value: 19888.49 , Gender: 1.0, Rate: 1.65, Age: 65.0,Installments : 72.0, Churn Prob: 0.96
# Client Id:2100.0, Value: 16817.72 , Gender: 0.0, Rate: 1.65, Age: 65.0,Installments : 72.0, Churn Prob: 0.91
# Client Id:2191.0, Value: 10297.32 , Gender: 1.0, Rate: 1.65, Age: 61.0,Installments : 72.0, Churn Prob: 0.87
# Client Id:2239.0, Value: 11308.47 , Gender: 1.0, Rate: 1.65, Age: 65.0,Installments : 72.0, Churn Prob: 0.97
# Client Id:2262.0, Value: 56627.57 , Gender: 1.0, Rate: 1.5, Age: 74.0,Installments : 36.0, Churn Prob: 0.93
# Client Id:2273.0, Value: 24906.18 , Gender: 1.0, Rate: 1.6, Age: 71.0,Installments : 48.0, Churn Prob: 0.9
# Client Id:2282.0, Value: 64910.25 , Gender: 0.0, Rate: 1.5, Age: 69.0,Installments : 48.0, Churn Prob: 0.97
# Client Id:2334.0, Value: 14648.88 , Gender: 1.0, Rate: 1.65, Age: 71.0,Installments : 48.0, Churn Prob: 0.92
# Client Id:2382.0, Value: 18543.28 , Gender: 1.0, Rate: 1.65, Age: 65.0,Installments : 72.0, Churn Prob: 0.91
# Client Id:2409.0, Value: 23647.78 , Gender: 1.0, Rate: 1.6, Age: 61.0,Installments : 72.0, Churn Prob: 0.93
# Client Id:2426.0, Value: 15725.75 , Gender: 1.0, Rate: 1.65, Age: 60.0,Installments : 72.0, Churn Prob: 0.97
# ------------------------------
# 448.94 + 459970.4643333333
# Atendente 1: day 1 clients: 42 , Male: 12.0 , Female: 30.0 , value 459970.4643333333, sequence [120, 126, 137, 153, 227, 334, 362, 390, 393, 409, 523, 595, 646, 855, 867, 948, 1028, 1141, 1277, 1322, 1371, 1379, 1469, 1583, 1695, 1759, 1819, 1835, 1889, 1935, 2069, 2131, 2170, 2189, 2243, 2278, 2313, 2337, 2369, 2390, 2398, 2401] , Mean Age : 63.04761904761905
# Client Id:120.0, Value: 9986.39 , Gender: 1.0, Rate: 1.7, Age: 63.0,Installments : 72.0, Churn Prob: 0.99
# Client Id:126.0, Value: 16211.38 , Gender: 1.0, Rate: 1.65, Age: 61.0,Installments : 72.0, Churn Prob: 0.95
# Client Id:137.0, Value: 15607.49 , Gender: 1.0, Rate: 1.65, Age: 70.0,Installments : 48.0, Churn Prob: 0.95
# Client Id:153.0, Value: 9622.3 , Gender: 1.0, Rate: 1.7, Age: 59.0,Installments : 72.0, Churn Prob: 0.92
# Client Id:227.0, Value: 18518.3 , Gender: 1.0, Rate: 1.65, Age: 75.0,Installments : 36.0, Churn Prob: 0.9
# Client Id:334.0, Value: 11202.52 , Gender: 1.0, Rate: 1.65, Age: 66.0,Installments : 72.0, Churn Prob: 0.91
# Client Id:362.0, Value: 19253.22 , Gender: 0.0, Rate: 1.65, Age: 59.0,Installments : 72.0, Churn Prob: 0.96
# Client Id:390.0, Value: 15750.06 , Gender: 1.0, Rate: 1.65, Age: 69.0,Installments : 48.0, Churn Prob: 0.93
# Client Id:393.0, Value: 22760.63 , Gender: 1.0, Rate: 1.6, Age: 72.0,Installments : 48.0, Churn Prob: 0.88
# Client Id:409.0, Value: 22687.74 , Gender: 1.0, Rate: 1.6, Age: 66.0,Installments : 72.0, Churn Prob: 0.94
# Client Id:523.0, Value: 17517.25 , Gender: 1.0, Rate: 1.65, Age: 60.0,Installments : 72.0, Churn Prob: 0.97
# Client Id
0,Installments : 72.0, Churn Prob: 0.97
# Client Id:629.0, Value: 21323.09 , Gender: 1.0, Rate: 1.6, Age: 75.0,Installments : 36.0, Churn Prob: 0.94
# Client Id:688.0, Value: 13957.39 , Gender: 1.0, Rate: 1.65, Age: 61.0,Installments : 72.0, Churn Prob: 0.93
# Client Id:718.0, Value: 13081.9 , Gender: 0.0, Rate: 1.65, Age: 62.0,Installments : 72.0, Churn Prob: 0.97
# Client Id:810.0, Value: 12623.25 , Gender: 0.0, Rate: 1.65, Age: 58.0,Installments : 72.0, Churn Prob: 0.92
# Client Id:910.0, Value: 25557.12 , Gender: 1.0, Rate: 1.6, Age: 58.0,Installments : 72.0, Churn Prob: 0.94
# Client Id:1027.0, Value: 14966.0 , Gender: 0.0, Rate: 1.65, Age: 61.0,Installments : 72.0, Churn Prob: 0.93
# Client Id:1053.0, Value: 15206.52 , Gender: 0.0, Rate: 1.65, Age: 55.0,Installments : 72.0, Churn Prob: 0.97
# Client Id:1100.0, Value: 42697.1 , Gender: 1.0, Rate: 1.5, Age: 59.0,Installments : 72.0, Churn Prob: 0.95
# Client Id:1191.0, Value: 9583.79 , Gender: 0.0, Rate: 1.7, Age: 65.0,Installments : 72.0, Churn Prob: 0.97
# Client Id:1195.0, Value: 16541.45 , Gender: 1.0, Rate: 1.65, Age: 63.0,Installments : 72.0, Churn Prob: 0.97
# Client Id:1211.0, Value: 49605.96 , Gender: 1.0, Rate: 1.5, Age: 69.0,Installments : 48.0, Churn Prob: 0.91
# Client Id:1300.0, Value: 17591.51 , Gender: 1.0, Rate: 1.65, Age: 74.0,Installments : 36.0, Churn Prob: 0.96
# Client Id:1349.0, Value: 9323.55 , Gender: 0.0, Rate: 1.7, Age: 60.0,Installments : 72.0, Churn Prob: 0.92
# Client Id:1376.0, Value: 11198.46 , Gender: 0.0, Rate: 1.65, Age: 57.0,Installments : 72.0, Churn Prob: 0.95
# Client Id:1418.0, Value: 22104.44 , Gender: 1.0, Rate: 1.6, Age: 62.0,Installments : 72.0, Churn Prob: 0.89
# Client Id:1423.0, Value: 46169.86 , Gender: 1.0, Rate: 1.5, Age: 63.0,Installments : 72.0, Churn Prob: 0.92
# Client Id:1424.0, Value: 12739.53 , Gender: 1.0, Rate: 1.65, Age: 56.0,Installments : 72.0, Churn Prob: 0.96
# Client Id:1471.0, Value: 23583.81 , Gender: 0.0, Rate: 1.6, Age: 71.0,Installments : 48.0, Churn Prob: 0.96
# Client Id:1480.0, Value: 23884.02 , Gender: 1.0, Rate: 1.6, Age: 55.0,Installments : 72.0, Churn Prob: 0.89
# Client Id:1489.0, Value: 27994.41 , Gender: 0.0, Rate: 1.6, Age: 73.0,Installments : 36.0, Churn Prob: 0.94
# Client Id:1496.0, Value: 28382.44 , Gender: 1.0, Rate: 1.6, Age: 70.0,Installments : 48.0, Churn Prob: 0.89
# Client Id:1515.0, Value: 17044.51 , Gender: 0.0, Rate: 1.65, Age: 71.0,Installments : 48.0, Churn Prob: 0.97
# Client Id:1580.0, Value: 23348.86 , Gender: 1.0, Rate: 1.6, Age: 56.0,Installments : 72.0, Churn Prob: 0.95
# Client Id:1595.0, Value: 25962.0 , Gender: 0.0, Rate: 1.6, Age: 72.0,Installments : 48.0, Churn Prob: 0.97
# Client Id:1600.0, Value: 27404.05 , Gender: 0.0, Rate: 1.6, Age: 63.0,Installments : 72.0, Churn Prob: 0.99
# Client Id:1639.0, Value: 21638.44 , Gender: 1.0, Rate: 1.6, Age: 61.0,Installments : 72.0, Churn Prob: 0.94
# Client Id:1655.0, Value: 29835.91 , Gender: 1.0, Rate: 1.6, Age: 72.0,Installments : 48.0, Churn Prob: 0.96
# Client Id:1675.0, Value: 27813.78 , Gender: 0.0, Rate: 1.6, Age: 70.0,Installments : 48.0, Churn Prob: 0.95
# Client Id:1687.0, Value: 16015.09 , Gender: 1.0, Rate: 1.65, Age: 58.0,Installments : 72.0, Churn Prob: 0.89
# Client Id:1690.0, Value: 12508.61 , Gender: 1.0, Rate: 1.65, Age: 59.0,Installments : 72.0, Churn Prob: 0.88
# Client Id:1698.0, Value: 28277.43 , Gender: 1.0, Rate: 1.6, Age: 68.0,Installments : 48.0, Churn Prob: 0.9
# Client Id:1738.0, Value: 23105.37 , Gender: 1.0, Rate: 1.6, Age: 68.0,Installments : 48.0, Churn Prob: 0.93
# Client Id:1814.0, Value: 24441.18 , Gender: 1.0, Rate: 1.6, Age: 60.0,Installments : 72.0, Churn Prob: 0.95
# Client Id:1903.0, Value: 18755.89 , Gender: 1.0, Rate: 1.65, Age: 56.0,Installments : 72.0, Churn Prob: 0.97
# Client Id:1948.0, Value: 19742.64 , Gender: 1.0, Rate: 1.65, Age: 64.0,Installments : 72.0, Churn Prob: 0.94
# Client Id:1985.0, Value: 27389.56 , Gender: 1.0, Rate: 1.6, Age: 58.0,Installments : 72.0, Churn Prob: 0.98
# Client Id:2099.0, Value: 35175.05 , Gender: 1.0, Rate: 1.5, Age: 63.0,Installments : 72.0, Churn Prob: 0.93
# Client Id:2113.0, Value: 17601.05 , Gender: 1.0, Rate: 1.65, Age: 57.0,Installments : 72.0, Churn Prob: 0.88
# Client Id:2186.0, Value: 9661.66 , Gender: 0.0, Rate: 1.7, Age: 66.0,Installments : 72.0, Churn Prob: 0.95
# ------------------------------
# 459.51 + 636538.581
# Atendente 1: day 3 clients: 42 , Male: 21.0 , Female: 21.0 , value 636538.581, sequence [415, 445, 453, 475, 483, 512, 515, 539, 551, 572, 577, 709, 733, 794, 887, 904, 926, 968, 1020, 1042, 1116, 1199, 1320, 1486, 1535, 1830, 1840, 1918, 1940, 1943, 1988, 2081, 2143, 2172, 2199, 2275, 2306, 2335, 2356, 2368, 2372, 2449] , Mean Age : 63.54761904761905
# Client Id:415.0, Value: 28413.89 , Gender: 1.0, Rate: 1.6, Age: 62.0,Installments : 72.0, Churn Prob: 0.88
# Client Id:445.0, Value: 25299.56 , Gender: 1.0, Rate: 1.6, Age: 68.0,Installments : 48.0, Churn Prob: 0.97
# Client Id:453.0, Value: 21857.83 , Gender: 1.0, Rate: 1.6, Age: 63.0,Installments : 72.0, Churn Prob: 0.94
# Client Id:475.0, Value: 62641.01 , Gender: 1.0, Rate: 1.5, Age: 61.0,Installments : 72.0, Churn Prob: 0.96
# Client Id:483.0, Value: 14742.72 , Gender: 1.0, Rate: 1.65, Age: 70.0,Installments : 48.0, Churn Prob: 0.91
# Client Id:512.0, Value: 16539.59 , Gender: 0.0, Rate: 1.65, Age: 65.0,Installments : 72.0, Churn Prob: 0.92
# Client Id:515.0, Value: 15358.11 , Gender: 0.0, Rate: 1.65, Age: 66.0,Installments : 72.0, Churn Prob: 0.98
# Client Id:539.0, Value: 24044.0 , Gender: 1.0, Rate: 1.6, Age: 57.0,Installments : 72.0, Churn Prob: 0.91
# Client Id:551.0, Value: 9557.73 , Gender: 0.0, Rate: 1.7, Age: 63.0,Installments : 72.0, Churn Prob: 0.99
# Client Id:572.0, Value: 18695.03 , Gender: 1.0, Rate: 1.65, Age: 63.0,Installments : 72.0, Churn Prob: 0.87
# Client Id:577.0, Value: 19738.66 , Gender: 1.0, Rate: 1.65, Age: 73.0,Installments : 36.0, Churn Prob: 0.97
# Client Id:709.0, Value: 10163.26 , Gender: 0.0, Rate: 1.65, Age: 65.0,Installments : 72.0, Churn Prob: 0.94
# Client Id:733.0, Value: 21361.39 , Gender: 0.0, Rate: 1.6, Age: 59.0,Installments : 72.0, Churn Prob: 0.89
# Client Id:794.0, Value: 10824.98 , Gender: 0.0, Rate: 1.65, Age: 58.0,Installments : 72.0, Churn Prob: 0.95
# Client Id:887.0, Value: 18204.85 , Gender: 1.0, Rate: 1.65, Age: 71.0,Installments : 48.0, Churn Prob: 0.9
# Client Id:904.0, Value: 12348.78 , Gender: 0.0, Rate: 1.65, Age: 61.0,Installments : 72.0, Churn Prob: 0.88
# Client Id:926.0, Value: 9266.99 , Gender: 1.0, Rate: 1.7, Age: 62.0,Installments : 72.0, Churn Prob: 0.89
# Client Id:968.0, Value: 18410.38 , Gender: 0.0, Rate: 1.65, Age: 58.0,Installments : 72.0, Churn Prob: 0.93
# Client Id:1020.0, Value: 10841.4 , Gender: 1.0, Rate: 1.65, Age: 58.0,Installments : 72.0, Churn Prob: 0.89
# Client Id:1042.0, Value: 27208.95 , Gender: 1.0, Rate: 1.6, Age: 63.0,Installments : 72.0, Churn Prob: 0.91
# Client Id:1116.0, Value: 14688.12 , Gender: 1.0, Rate: 1.65, Age: 66.0,Installments : 72.0, Churn Prob: 0.9
# Client Id:1199.0, Value: 69258.24 , Gender: 0.0, Rate: 1.5, Age: 59.0,Installments : 72.0, Churn Prob: 0.93
# ...
# Client Id:2146.0, Value: 23800.74 , Gender: 1.0, Rate: 1.6, Age: 59.0,Installments : 72.0, Churn Prob: 0.92
# Client Id:2241.0, Value: 15077.65 , Gender: 1.0, Rate: 1.65, Age: 72.0,Installments : 48.0, Churn Prob: 0.96
# Client Id:2255.0, Value: 27990.26 , Gender: 1.0, Rate: 1.6, Age: 56.0,Installments : 72.0, Churn Prob: 0.95
# Client Id:2259.0, Value: 17553.33 , Gender: 1.0, Rate: 1.65, Age: 61.0,Installments : 72.0, Churn Prob: 0.88
# Client Id:2319.0, Value: 50334.56 , Gender: 1.0, Rate: 1.5, Age: 63.0,Installments : 72.0, Churn Prob: 0.93
# Client Id:2364.0, Value: 10730.52 , Gender: 1.0, Rate: 1.65, Age: 62.0,Installments : 72.0, Churn Prob: 0.92
# Client Id:2377.0, Value: 22545.87 , Gender: 1.0, Rate: 1.6, Age: 58.0,Installments : 72.0, Churn Prob: 0.92
# Client Id:2396.0, Value: 24394.36 , Gender: 1.0, Rate: 1.6, Age: 74.0,Installments : 36.0, Churn Prob: 0.88
# Client Id:2403.0, Value: 10333.54 , Gender: 0.0, Rate: 1.65, Age: 58.0,Installments : 72.0, Churn Prob: 0.88
# Client Id:2412.0, Value: 23086.57 , Gender: 1.0, Rate: 1.6, Age: 63.0,Installments : 72.0, Churn Prob: 0.91
# ------------------------------
# 464.71 + 701295.3453333332
# Atendente 3: day 2 clients: 42 , Male: 23.0 , Female: 19.0 , value 701295.3453333332, sequence [684, 753, 908, 938, 977, 1084, 1098, 1155, 1274, 1355, 1393, 1405, 1442, 1455, 1487, 1503, 1508, 1510, 1518, 1532, 1588, 1598, 1602, 1632, 1637, 1648, 1662, 1672, 1691, 1692, 1718, 1725, 1775, 1800, 1818, 1827, 1973, 2014, 2028, 2193, 2291, 2295] , Mean Age : 62.92857142857143
# Client Id:684.0, Value: 15319.08 , Gender: 0.0, Rate: 1.65, Age: 58.0,Installments : 72.0, Churn Prob: 0.88
# Client Id:753.0, Value: 17491.6 , Gender: 0.0, Rate: 1.65, Age: 55.0,Installments : 72.0, Churn Prob: 0.92
# Client Id:908.0, Value: 18637.28 , Gender: 0.0, Rate: 1.65, Age: 70.0,Installments : 48.0, Churn Prob: 0.98
# Client Id:938.0, Value: 24042.24 , Gender: 1.0, Rate: 1.6, Age: 55.0,Installments : 72.0, Churn Prob: 0.96
# Client Id:977.0, Value: 16229.55 , Gender: 0.0, Rate: 1.65, Age: 69.0,Installments : 48.0, Churn Prob: 0.95
# Client Id:1084.0, Value: 26865.83 , Gender: 1.0, Rate: 1.6, Age: 57.0,Installments : 72.0, Churn Prob: 0.92
# Client Id:1098.0, Value: 18792.11 , Gender: 1.0, Rate: 1.65, Age: 63.0,Installments : 72.0, Churn Prob: 0.87
# Client Id:1155.0, Value: 14192.54 , Gender: 0.0, Rate: 1.65, Age: 67.0,Installments : 48.0, Churn Prob: 0.92
# Client Id:1274.0, Value: 23546.75 , Gender: 0.0, Rate: 1.6, Age: 59.0,Installments : 72.0, Churn Prob: 0.9
# Client Id:1355.0, Value: 16110.39 , Gender: 1.0, Rate: 1.65, Age: 62.0,Installments : 72.0, Churn Prob: 0.98
# Client Id:1393.0, Value: 62427.31 , Gender: 0.0, Rate: 1.5, Age: 59.0,Installments : 72.0, Churn Prob: 0.91
# Client Id:1405.0, Value: 18062.32 , Gender: 0.0, Rate: 1.65, Age: 69.0,Installments : 48.0, Churn Prob: 0.88
# Client Id:1442.0, Value: 40828.32 , Gender: 1.0, Rate: 1.5, Age: 71.0,Installments : 48.0, Churn Prob: 0.87
# Client Id:1455.0, Value: 23372.79 , Gender: 1.0, Rate: 1.6, Age: 61.0,Installments : 72.0, Churn Prob: 0.89
# Client Id:1487.0, Value: 24438.57 , Gender: 0.0, Rate: 1.6, Age: 66.0,Installments : 72.0, Churn Prob: 0.87
# Client Id:1503.0, Value: 9613.22 , Gender: 1.0, Rate: 1.7, Age: 56.0,Installments : 72.0, Churn Prob: 0.94
# Client Id:1508.0, Value: 15437.86 , Gender: 0.0, Rate: 1.65, Age: 61.0,Installments : 72.0, Churn Prob: 0.91
# Client Id:1510.0, Value: 16853.02 , Gender: 0.0, Rate: 1.65, Age: 66.0,Installments : 72.0, Churn Prob: 0.89
# Client Id:1518.0, Value: 22911.09 , Gender: 0.0, Rate: 1.6, Age: 72.0,Installments : 48.0, Churn Prob: 0.88
# Client Id:1532.0, Value: 11914.55 , Gender: 1.0, Rate: 1.65, Age: 66.0,Installments : 72.0, Churn Prob: 0.91
# Client Id:1588.0, Value: 26399.19 , Gender: 0.0, Rate: 1.6, Age: 56.0,Installments : 72.0, Churn Prob: 0.91
# Client Id:1598.0, Value: 29896.04 , Gender: 1.0, Rate: 1.6, Age: 63.0,Installments : 72.0, Churn Prob: 0.95
# Client Id:1602.0, Value: 23729.83 , Gender: 0.0, Rate: 1.6, Age: 62.0,Installments : 72.0, Churn Prob: 0.92
# Client Id:1632.0, Value: 22982.27 , Gender: 0.0, Rate: 1.6, Age: 72.0,Installments : 48.0, Churn Prob: 0.89
# Client Id:1637.0, Value: 27737.02 , Gender: 0.0, Rate: 1.6, Age: 61.0,Installments : 72.0, Churn Prob: 0.94
# Client Id:1648.0, Value: 53839.94 , Gender: 1.0, Rate: 1.5, Age: 62.0,Installments : 72.0, Churn Prob: 0.96
# Client Id:1662.0, Value: 21173.08 , Gender: 0.0, Rate: 1.6, Age: 61.0,Installments : 72.0, Churn Prob: 0.93
# Client Id:1672.0, Value: 16341.82 , Gender: 0.0, Rate: 1.65, Age: 72.0,Installments : 48.0, Churn Prob: 0.87
# Client Id:1691.0, Value: 13518.33 , Gender: 1.0, Rate: 1.65, Age: 64.0,Installments : 72.0, Churn Prob: 0.87
# Client Id:1692.0, Value: 58659.32 , Gender: 1.0, Rate: 1.5, Age: 61.0,Installments : 72.0, Churn Prob: 0.97
# Client Id:1718.0, Value: 29815.98 , Gender: 0.0, Rate: 1.6, Age: 74.0,Installments : 36.0, Churn Prob: 0.92
# Client Id:1725.0, Value: 64147.06 , Gender: 1.0, Rate: 1.5, Age: 59.0,Installments : 72.0, Churn Prob: 0.93
# Client Id:1775.0, Value: 23185.93 , Gender: 1.0, Rate: 1.6, Age: 68.0,Installments : 48.0, Churn Prob: 0.92
# Client Id:1800.0, Value: 28394.3 , Gender: 0.0, Rate: 1.6, Age: 58.0,Installments : 72.0, Churn Prob: 0.95
# Client Id:1818.0, Value: 14185.87 , Gender: 1.0, Rate: 1.65, Age: 58.0,Installments : 72.0, Churn Prob: 0.99
# Client Id:1827.0, Value: 27523.94 , Gender: 1.0, Rate: 1.6, Age: 61.0,Installments : 72.0, Churn Prob: 0.91
# Client Id:1973.0, Value: 32639.19 , Gender: 1.0, Rate: 1.5, Age: 63.0,Installments : 72.0, Churn Prob: 0.97
# Client Id:2014.0, Value: 14306.69 , Gender: 0.0, Rate: 1.65, Age: 56.0,Installments : 72.0, Churn Prob: 0.93
# Client Id:2028.0, Value: 15024.52 , Gender: 1.0, Rate: 1.65, Age: 55.0,Installments : 72.0, Churn Prob: 0.95
# Client Id:2193.0, Value: 13934.72 , Gender: 0.0, Rate: 1.65, Age: 65.0,Installments : 72.0, Churn Prob: 0.95
# Client Id:2291.0, Value: 36871.26 , Gender: 1.0, Rate: 1.5, Age: 66.0,Installments : 72.0, Churn Prob: 0.96
# Client Id:2295.0, Value: 14533.84 , Gender: 0.0, Rate: 1.65, Age: 64.0,Installments : 72.0, Churn Prob: 0.92
# ------------------------------
# 464.5 + 685965.9706666666
# Atendente 3: day 3 clients: 42 , Male: 21.0 , Female: 21.0 , value 685965.9706666666, sequence [426, 466, 480, 491, 508, 516, 519, 528, 529, 552, 554, 562, 565, 583, 587, 639, 661, 693, 704, 893, 979, 1010, 1074, 1077, 1157, 1197, 1219, 1454, 1877, 1923, 1986, 2053, 2060, 2128, 2249, 2258, 2261, 2303, 2315, 2344, 2365, 2404] , Mean Age : 63.0
# Client Id:426.0, Value: 9782.8 , Gender: 1.0, Rate: 1.7, Age: 64.0,Installments : 72.0, Churn Prob: 0.87
# Client Id:466.0, Value: 19151.48 , Gender: 1.0, Rate: 1.65, Age: 63.0,Installments : 72.0, Churn Prob: 0.95
# Client Id:480.0, Value: 23941.54 , Gender: 1.0, Rate: 1.6, Age: 67.0,Installments : 48.0, Churn Prob: 0.98
# Client Id:491.0, Value: 22375.73 , Gender: 1.0, Rate: 1.6, Age: 63.0,Installments : 72.0, Churn Prob: 0.95
# Client Id:508.0, Value: 19964.46 , Gender: 1.0, Rate: 1.65, Age: 57.0,Installments : 72.0, Churn Prob: 0.94
# Client Id:516.0, Value: 16882.74 , Gender: 1.0, Rate: 1.65, Age: 59.0,Installments : 72.0, Churn Prob: 0.93
# Client Id:519.0, Value: 9831.44 , Gender: 0.0, Rate: 1.7, Age: 63.0,Installments : 72.0, Churn Prob: 0.93
# Client Id:528.0, Value: 12893.36 , Gender: 0.0, Rate: 1.65, Age: 59.0,Installments : 72.0, Churn Prob: 0.89
# Client Id:529.0, Value: 18335.76 , Gender: 1.0, Rate: 1.65, Age: 63.0,Installments : 72.0, Churn Prob: 0.93
# Client Id:552.0, Value: 22327.13 , Gender: 0.0, Rate: 1.6, Age: 58.0,Installments : 72.0, Churn Prob: 0.89
# Client Id:554.0, Value: 10603.69 , Gender: 1.0, Rate: 1.65, Age: 64.0,Installments : 72.0, Churn Prob: 0.96
# Client Id:562.0, Value: 18868.77 , Gender: 0.0, Rate: 1.65, Age: 62.0,Installments : 72.0, Churn Prob: 0.96
# Client Id:565.0, Value: 46925.15 , Gender: 1.0, Rate: 1.5, Age: 65.0,Installments : 72.0, Churn Prob: 0.96
# Client Id:583.0, Value: 20646.56 , Gender: 1.0, Rate: 1.6, Age: 65.0,Installments : 72.0, Churn Prob: 0.92
# Client Id:587.0, Value: 22544.17 , Gender: 1.0, Rate: 1.6, Age: 57.0,Installments : 72.0, Churn Prob: 0.87
# Client Id:639.0, Value: 20459.1 , Gender: 1.0, Rate: 1.6, Age: 66.0,Installments : 72.0, Churn Prob: 0.94
# Client Id:661.0, Value: 30822.34 , Gender: 1.0, Rate: 1.5, Age: 56.0,Installments : 72.0, Churn Prob: 0.96
# Client Id:693.0, Value: 17380.05 , Gender: 0.0, Rate: 1.65, Age: 69.0,Installments : 48.0, Churn Prob: 0.96
# Client Id:704.0, Value: 26446.99 , Gender: 1.0, Rate: 1.6, Age: 65.0,Installments : 72.0, Churn Prob: 0.88
# Client Id:893.0, Value: 19923.85 , Gender: 0.0, Rate: 1.65, Age: 65.0,Installments : 72.0, Churn Prob: 0.91
# Client Id:979.0, Value: 24931.46 , Gender: 1.0, Rate: 1.6, Age: 62.0,Installments : 72.0, Churn Prob: 0.9
# Client Id:1010.0, Value: 31150.92 , Gender: 0.0, Rate: 1.5, Age: 61.0,Installments : 72.0, Churn Prob: 0.97
# Client Id:1074.0, Value: 28176.15 , Gender: 0.0, Rate: 1.6, Age: 56.0,Installments : 72.0, Churn Prob: 0.88
# Client Id:1077.0, Value: 26510.26 , Gender: 1.0, Rate: 1.6, Age: 71.0,Installments : 48.0, Churn Prob: 0.95
# Client Id:1157.0, Value: 29830.24 , Gender: 0.0, Rate: 1.6, Age: 70.0,Installments : 48.0, Churn Prob: 0.9
# Client Id:1197.0, Value: 37767.88 , Gender: 1.0, Rate: 1.5, Age: 66.0,Installments : 72.0, Churn Prob: 0.93
# Client Id:1219.0, Value: 29935.46 , Gender: 0.0, Rate: 1.6, Age: 60.0,Installments : 72.0, Churn Prob: 0.95
# Client Id:1454.0, Value: 9103.22 , Gender: 0.0, Rate: 1.7, Age: 63.0,Installments : 72.0, Churn Prob: 0.93
# Client Id:1877.0, Value: 27279.15 , Gender: 0.0, Rate: 1.6, Age: 57.0,Installments : 72.0, Churn Prob: 0.95
# Client Id:1923.0, Value: 10920.86 , Gender: 0.0, Rate: 1.65, Age: 59.0,Installments : 72.0, Churn Prob: 0.99
# Client Id:1986.0, Value: 11195.23 , Gender: 1.0, Rate: 1.65, Age: 64.0,Installments : 72.0, Churn Prob: 0.92
# Client Id:2053.0, Value: 21006.75 , Gender: 1.0, Rate: 1.6, Age: 71.0,Installments : 48.0, Churn Prob: 0.94
# Client Id:2060.0, Value: 21870.72 , Gender: 0.0, Rate: 1.6, Age: 56.0,Installments : 72.0, Churn Prob: 0.97
# Client Id:2128.0, Value: 60987.67 , Gender: 0.0, Rate: 1.5, Age: 56.0,Installments : 72.0, Churn Prob: 0.98
# Client Id:2249.0, Value: 19837.09 , Gender: 0.0, Rate: 1.65, Age: 66.0,Installments : 72.0, Churn Prob: 0.96
# Client Id:2258.0, Value: 26947.76 , Gender: 0.0, Rate: 1.6, Age: 63.0,Installments : 72.0, Churn Prob: 0.95
# Client Id:2261.0, Value: 50079.45 , Gender: 1.0, Rate: 1.5, Age: 70.0,Installments : 48.0, Churn Prob: 0.93
# Client Id:2303.0, Value: 62017.1 , Gender: 0.0, Rate: 1.5, Age: 62.0,Installments : 72.0, Churn Prob: 0.98
# Client Id:2315.0, Value: 17055.25 , Gender: 0.0, Rate: 1.65, Age: 70.0,Installments : 48.0, Churn Prob: 0.96
# Client Id:2344.0, Value: 13302.37 , Gender: 1.0, Rate: 1.65, Age: 64.0,Installments : 72.0, Churn Prob: 0.92
# Client Id:2365.0, Value: 22658.59 , Gender: 0.0, Rate: 1.6, Age: 58.0,Installments : 72.0, Churn Prob: 0.88
# Client Id:2404.0, Value: 20719.39 , Gender: 0.0, Rate: 1.6, Age: 71.0,Installments : 48.0, Churn Prob: 0.98
# ------------------------------
# 455.18 + 544139.2576666666
# Atendente 3: day 4 clients: 42 , Male: 21.0 , Female: 21.0 , value 544139.2576666666, sequence [6, 10, 146, 228, 254, 265, 272, 326, 347, 351, 451, 511, 605, 621, 694, 739, 809, 831, 854, 996, 1031, 1051, 1052, 1109, 1120, 1162, 1201, 1263, 1270, 1337, 1362, 1403, 1472, 1627, 1680, 1939, 1983, 2022, 2072, 2141, 2417, 2439] , Mean Age : 64.66666666666667
# Client Id:6.0, Value: 16444.2 , Gender: 0.0, Rate: 1.65, Age: 66.0,Installments : 72.0, Churn Prob: 0.96
# Client Id:10.0, Value: 26230.86 , Gender: 1.0, Rate: 1.6, Age: 61.0,Installments : 72.0, Churn Prob: 0.96
# Client Id:146.0, Value: 18700.52 , Gender: 1.0, Rate: 1.65, Age: 68.0,Installments : 48.0, Churn Prob: 0.94
# Client Id:228.0, Value: 55980.86 , Gender: 0.0, Rate: 1.5, Age: 71.0,Installments : 48.0, Churn Prob: 0.94
# Client Id:254.0, Value: 18304.18 , Gender: 1.0, Rate: 1.65, Age: 59.0,Installments : 72.0, Churn Prob: 0.92
# Client Id:265.0, Value: 20368.79 , Gender: 0.0, Rate: 1.6, Age: 63.0,Installments : 72.0, Churn Prob: 0.98
# Client Id:272.0, Value: 29695.11 , Gender: 1.0, Rate: 1.6, Age: 66.0,Installments : 72.0, Churn Prob: 0.88
# Client Id:326.0, Value: 13614.83 , Gender: 1.0, Rate: 1.65, Age: 65.0,Installments : 72.0, Churn Prob: 0.91
# Client Id:347.0, Value: 9091.82 , Gender: 0.0, Rate: 1.7, Age: 64.0,Installments : 72.0, Churn Prob: 0.91
# Client Id:351.0, Value: 26309.05 , Gender: 0.0, Rate: 1.6, Age: 60.0,Installments : 72.0, Churn Prob: 0.99
# Client Id:451.0, Value: 18971.31 , Gender: 0.0, Rate: 1.65, Age: 70.0,Installments : 48.0, Churn Prob: 0.97
# Client Id:511.0, Value: 9181.87 , Gender: 0.0, Rate: 1.7, Age: 62.0,Installments : 72.0, Churn Prob: 0.98
# Client Id:605.0, Value: 33963.78 , Gender: 1.0, Rate: 1.5, Age: 55.0,Installments : 72.0, Churn Prob: 0.98
# Client Id:621.0, Value: 9625.76 , Gender: 0.0, Rate: 1.7, Age: 57.0,Installments : 72.0, Churn Prob: 0.98
# Client Id:694.0, Value: 21895.31 , Gender: 1.0, Rate: 1.6, Age: 63.0,Installments : 72.0, Churn Prob: 0.98
# Client Id:739.0, Value: 19959.47 , Gender: 1.0, Rate: 1.65, Age: 62.0,Installments : 72.0, Churn Prob: 0.98
# Client Id:809.0, Value: 26455.62 , Gender: 0.0, Rate: 1.6, Age: 73.0,Installments : 36.0, Churn Prob: 0.96
# Client Id:831.0, Value: 13469.63 , Gender: 1.0, Rate: 1.65, Age: 63.0,Installments : 72.0, Churn Prob: 0.99
# Client Id:854.0, Value: 10628.26 , Gender: 0.0, Rate: 1.65, Age: 60.0,Installments : 72.0, Churn Prob: 0.99
# Client Id:996.0, Value: 20606.19 , Gender: 0.0, Rate: 1.6, Age: 69.0,Installments : 48.0, Churn Prob: 0.96
# Client Id:1031.0, Value: 12874.0 , Gender: 1.0, Rate: 1.65, Age: 61.0,Installments : 72.0, Churn Prob: 0.96
# Client Id:1051.0, Value: 14638.24 , Gender: 0.0, Rate: 1.65, Age: 65.0,Installments : 72.0, Churn Prob: 0.92
# Client Id:1052.0, Value: 49132.17 , Gender: 1.0, Rate: 1.5, Age: 71.0,Installments : 48.0, Churn Prob: 0.93
# Client Id:1109.0, Value: 9094.77 , Gender: 0.0, Rate: 1.7, Age: 65.0,Installments : 72.0, Churn Prob: 0.99
# Client Id:1120.0, Value: 9101.48 , Gender: 0.0, Rate: 1.7, Age: 60.0,Installments : 72.0, Churn Prob: 0.88
# Client Id:1162.0, Value: 18992.83 , Gender: 0.0, Rate: 1.65, Age: 67.0,Installments : 48.0, Churn Prob: 0.87
# Client Id:1201.0, Value: 13333.21 , Gender: 1.0, Rate: 1.65, Age: 56.0,Installments : 72.0, Churn Prob: 0.91
# Client Id:1263.0, Value: 30933.63 , Gender: 0.0, Rate: 1.5, Age: 64.0,Installments : 72.0, Churn Prob: 0.92
# Client Id:1270.0, Value: 20247.55 , Gender: 1.0, Rate: 1.6, Age: 69.0,Installments : 48.0, Churn Prob: 0.95
# Client Id:1337.0, Value: 17741.58 , Gender: 1.0, Rate: 1.65, Age: 73.0,Installments : 36.0, Churn Prob: 0.97
# Client Id:1362.0, Value: 21722.01 , Gender: 0.0, Rate: 1.6, Age: 72.0,Installments : 48.0, Churn Prob: 0.87
# Client Id:1403.0, Value: 10494.96 , Gender: 1.0, Rate: 1.65, Age: 60.0,Installments : 72.0, Churn Prob: 0.97
# Client Id:1472.0, Value: 10366.29 , Gender: 0.0, Rate: 1.65, Age: 60.0,Installments : 72.0, Churn Prob: 0.92
# Client Id:1627.0, Value: 9901.94 , Gender: 1.0, Rate: 1.7, Age: 57.0,Installments : 72.0, Churn Prob: 0.87
# Client Id:1680.0, Value: 15212.85 , Gender: 1.0, Rate: 1.65, Age: 71.0,Installments : 48.0, Churn Prob: 0.93
# Client Id:1939.0, Value: 23786.74 , Gender: 0.0, Rate: 1.6, Age: 70.0,Installments : 48.0, Churn Prob: 0.98
# Client Id:1983.0, Value: 26316.82 , Gender: 0.0, Rate: 1.6, Age: 59.0,Installments : 72.0, Churn Prob: 0.99
# Client Id:2022.0, Value: 16966.74 , Gender: 0.0, Rate: 1.65, Age: 68.0,Installments : 48.0, Churn Prob: 0.9
# Client Id:2072.0, Value: 64116.67 , Gender: 1.0, Rate: 1.5, Age: 68.0,Installments : 48.0, Churn Prob: 0.87
# Client Id:2141.0, Value: 24986.52 , Gender: 1.0, Rate: 1.6, Age: 70.0,Installments : 48.0, Churn Prob: 0.89
# Client Id:2417.0, Value: 17092.33 , Gender: 1.0, Rate: 1.65, Age: 65.0,Installments : 72.0, Churn Prob: 0.89
# Client Id:2439.0, Value: 32632.56 , Gender: 1.0, Rate: 1.5, Age: 68.0,Installments : 48.0, Churn Prob: 0.97
# ------------------------------
# 850

# %%
https://medium.com/opex-analytics/machine-learning-using-mixed-integer-programming-af95e4d56863
# Out:
#   Cell In[17], line 1
#     https://medium.com/opex-analytics/machine-learning-using-mixed-integer-programming-af95e4d56863
#           ^
# SyntaxError: invalid syntax
